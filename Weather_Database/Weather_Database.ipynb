# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# Import the requests library.
import requests

#import the citipy module 
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
city
# Out:
# 'kapaa'

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ccc86899c384315fd0735dc4a85854e1

# %%
# Retrieve information for each city from the API call.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | arlit
# Processing Record 2 of Set 13 | norman wells
# Processing Record 3 of Set 13 | nome
# Processing Record 4 of Set 13 | nikolskoye
# Processing Record 5 of Set 13 | provideniya
# Processing Record 6 of Set 13 | chuy
# Processing Record 7 of Set 13 | san cristobal
# Processing Record 8 of Set 13 | lethem
# Processing Record 9 of Set 13 | upington
# Processing Record 10 of Set 13 | tiksi
# Processing Record 11 of Set 13 | albany
# Processing Record 12 of Set 13 | rikitea
# Processing Record 13 of Set 13 | souillac
# Processing Record 14 of Set 13 | butaritari
# Processing Record 15 of Set 13 | saint-philippe
# Processing Record 16 of Set 13 | balclutha
# Processing Record 17 of Set 13 | lavrentiya
# Processing Record 18 of Set 13 | sabinas
# Processing Record 19 of Set 13 | kavieng
# Processing Record 20 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 13 | bredasdorp
# Processing Record 22 of Set 13 | tura
# Processing Record 23 of Set 13 | kashi
# Processing Record 24 of Set 13 | korop
# Processing Record 25 of Set 13 | puerto ayora
# Processing Record 26 of Set 13 | lazaro cardenas
# Processing Record 27 of Set 13 | broome
# Processing Record 28 of Set 13 | thompson
# Processing Record 29 of Set 13 | mataura
# Processing Record 30 of Set 13 | leua
# Processing Record 31 of Set 13 | avarua
# Processing Record 32 of Set 13 | longyearbyen
# Processing Record 33 of Set 13 | haines junction
# Processing Record 34 of Set 13 | aksarka
# Processing Record 35 of Set 13 | labuhan
# Processing Record 36 of Set 13 | new norfolk
# Processing Record 37 of Set 13 | busselton
# Processing Record 38 of Set 13 | victoria
# Processing Record 39 of Set 13 | tasiilaq
# Processing Record 40 of Set 13 | kalmar
# Processing Record 41 of Set 13 | hobart
# Processing Record 42 of Set 13 | port elizabeth
# Processing Record 43 of Set 13 | wewak
# Processing Record 44 of Set 13 | alofi
# Processing Record 45 of Set 13 | hermanus
# Processing Record 46 of Set 13 | cape town
# Processing Record 47 of Set 13 | verdun
# Processing Record 48 of Set 13 | cabedelo
# Processing Record 49 of Set 13 | ponta do sol
# Processing Record 50 of Set 13 | port hardy
# Processing Record 1 of Set 14 | itinga
# Processing Record 2 of Set 14 | ribeira grande
# Processing Record 3 of Set 14 | salalah
# Processing Record 4 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 14 | sao filipe
# Processing Record 6 of Set 14 | vinh long
# Processing Record 7 of Set 14 | bluff
# Processing Record 8 of Set 14 | mpigi
# Processing Record 9 of Set 14 | saskylakh
# Processing Record 10 of Set 14 | redlands
# Processing Record 11 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 13 of Set 14 | hosakote
# Processing Record 14 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 14 | asau
# Processing Record 17 of Set 14 | atuona
# Processing Record 18 of Set 14 | doha
# Processing Record 19 of Set 14 | olafsvik
# Processing Record 20 of Set 14 | coquimbo
# Processing Record 21 of Set 14 | bonavista
# Processing Record 22 of Set 14 | enfield
# Processing Record 23 of Set 14 | bethel
# Processing Record 24 of Set 14 | kaitangata
# Processing Record 25 of Set 14 | viedma
# Processing Record 26 of Set 14 | hovd
# Processing Record 27 of Set 14 | dikson
# Processing Record 28 of Set 14 | barra patuca
# Processing Record 29 of Set 14 | talnakh
# Processing Record 30 of Set 14 | cedar city
# Processing Record 31 of Set 14 | gamba
# Processing Record 32 of Set 14 | tricase
# Processing Record 33 of Set 14 | noumea
# Processing Record 34 of Set 14 | palmerston north
# Processing Record 35 of Set 14 | linhares
# Processing Record 36 of Set 14 | upernavik
# Processing Record 37 of Set 14 | nyurba
# Processing Record 38 of Set 14 | iqaluit
# Processing Record 39 of Set 14 | saint george
# Processing Record 40 of Set 14 | abong mbang
# Processing Record 41 of Set 14 | buchanan
# Processing Record 42 of Set 14 | tuktoyaktuk
# Processing Record 43 of Set 14 | lara
# Processing Record 44 of Set 14 | semey
# Processing Record 45 of Set 14 | touros
# Processing Record 46 of Set 14 | barrow
# Processing Record 47 of Set 14 | yellowknife
# Processing Record 48 of Set 14 | kapaa
# Processing Record 49 of Set 14 | nyrob
# Processing Record 50 of Set 14 | tiarei
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | esperance
# Processing Record 3 of Set 15 | puro
# Processing Record 4 of Set 15 | sovetskiy
# Processing Record 5 of Set 15 | mahebourg
# Processing Record 6 of Set 15 | ushuaia
# Processing Record 7 of Set 15 | punta arenas
# Processing Record 8 of Set 15 | bengkulu
# Processing Record 9 of Set 15 | hamilton
# Processing Record 10 of Set 15 | hazorasp
# Processing Record 11 of Set 15 | samarinda
# Processing Record 12 of Set 15 | tigil
# Processing Record 13 of Set 15 | rockford
# Processing Record 14 of Set 15 | hilo
# Processing Record 15 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 15 | mao
# Processing Record 17 of Set 15 | castro
# Processing Record 18 of Set 15 | georgetown
# Processing Record 19 of Set 15 | venray
# Processing Record 20 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 15 | whitehorse
# Processing Record 22 of Set 15 | qaanaaq
# Processing Record 23 of Set 15 | sitka
# Processing Record 24 of Set 15 | rakaia
# Processing Record 25 of Set 15 | launceston
# Processing Record 26 of Set 15 | bergerac
# Processing Record 27 of Set 15 | lasa
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | vaini
# Processing Record 30 of Set 15 | olinda
# Processing Record 31 of Set 15 | toora-khem
# Processing Record 32 of Set 15 | port alfred
# Processing Record 33 of Set 15 | havoysund
# Processing Record 34 of Set 15 | jamestown
# Processing Record 35 of Set 15 | auki
# Processing Record 36 of Set 15 | marsabit
# Processing Record 37 of Set 15 | bogalusa
# Processing Record 38 of Set 15 | afonso claudio
# Processing Record 39 of Set 15 | husavik
# Processing Record 40 of Set 15 | bathsheba
# Processing Record 41 of Set 15 | carutapera
# Processing Record 42 of Set 15 | saint-louis
# Processing Record 43 of Set 15 | kavaratti
# Processing Record 44 of Set 15 | east london
# Processing Record 45 of Set 15 | paoua
# Processing Record 46 of Set 15 | manggar
# Processing Record 47 of Set 15 | itarema
# Processing Record 48 of Set 15 | arandis
# Processing Record 49 of Set 15 | kochi
# Processing Record 50 of Set 15 | thurso
# Processing Record 1 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 16 | luocheng
# Processing Record 3 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 16 | alekseyevsk
# Processing Record 5 of Set 16 | narrabri
# Processing Record 6 of Set 16 | puerto escondido
# Processing Record 7 of Set 16 | thinadhoo
# Processing Record 8 of Set 16 | haapiti
# Processing Record 9 of Set 16 | arraial do cabo
# Processing Record 10 of Set 16 | russell
# Processing Record 11 of Set 16 | nampula
# Processing Record 12 of Set 16 | atikokan
# Processing Record 13 of Set 16 | fairbanks
# Processing Record 14 of Set 16 | jurm
# Processing Record 15 of Set 16 | san bartolo
# Processing Record 16 of Set 16 | hofn
# Processing Record 17 of Set 16 | vao
# Processing Record 18 of Set 16 | cotonou
# Processing Record 19 of Set 16 | bjorkelangen
# Processing Record 20 of Set 16 | quelimane
# Processing Record 21 of Set 16 | anchorage
# Processing Record 22 of Set 16 | zwedru
# Processing Record 23 of Set 16 | sobolevo
# Processing Record 24 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 16 | kodiak
# Processing Record 26 of Set 16 | khatanga
# Processing Record 27 of Set 16 | rawson
# Processing Record 28 of Set 16 | hay river
# Processing Record 29 of Set 16 | padang
# Processing Record 30 of Set 16 | wa
# City not found. Skipping...
# Processing Record 31 of Set 16 | alyangula
# Processing Record 32 of Set 16 | pevek
# Processing Record 33 of Set 16 | vaitape
# Processing Record 34 of Set 16 | lewistown
# Processing Record 35 of Set 16 | kabale
# Processing Record 36 of Set 16 | george
# Processing Record 37 of Set 16 | oktyabrskiy
# Processing Record 38 of Set 16 | ukiah
# Processing Record 39 of Set 16 | bambous virieux
# Processing Record 40 of Set 16 | san juan
# Processing Record 41 of Set 16 | ibb
# Processing Record 42 of Set 16 | antofagasta
# Processing Record 43 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 16 | belaya gora
# Processing Record 45 of Set 16 | semme
# Processing Record 46 of Set 16 | ahipara
# Processing Record 47 of Set 16 | kushima
# Processing Record 48 of Set 16 | carberry
# Processing Record 49 of Set 16 | vanavara
# Processing Record 50 of Set 16 | marshfield

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
