# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# Import the requests library.
import requests

#import the citipy module 
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
city
# Out:
# 'jamestown'

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 633

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ccc86899c384315fd0735dc4a85854e1

# %%
# Retrieve information for each city from the API call.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = str(city_weather["weather"][0]["description"])
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | saint george
# Processing Record 2 of Set 13 | codrington
# Processing Record 3 of Set 13 | rikitea
# Processing Record 4 of Set 13 | albany
# Processing Record 5 of Set 13 | vila velha
# Processing Record 6 of Set 13 | batagay-alyta
# Processing Record 7 of Set 13 | hobart
# Processing Record 8 of Set 13 | bluff
# Processing Record 9 of Set 13 | nikolskoye
# Processing Record 10 of Set 13 | shimoda
# Processing Record 11 of Set 13 | olden
# Processing Record 12 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 13 | cape town
# Processing Record 14 of Set 13 | kandrian
# Processing Record 15 of Set 13 | port shepstone
# Processing Record 16 of Set 13 | panzhihua
# Processing Record 17 of Set 13 | chengde
# Processing Record 18 of Set 13 | arraial do cabo
# Processing Record 19 of Set 13 | patnos
# Processing Record 20 of Set 13 | evensk
# Processing Record 21 of Set 13 | qaanaaq
# Processing Record 22 of Set 13 | esperance
# Processing Record 23 of Set 13 | egvekinot
# Processing Record 24 of Set 13 | severo-kurilsk
# Processing Record 25 of Set 13 | kapaa
# Processing Record 26 of Set 13 | husavik
# Processing Record 27 of Set 13 | mataura
# Processing Record 28 of Set 13 | clyde river
# Processing Record 29 of Set 13 | vaini
# Processing Record 30 of Set 13 | mar del plata
# Processing Record 31 of Set 13 | cidreira
# Processing Record 32 of Set 13 | lata
# Processing Record 33 of Set 13 | mto wa mbu
# Processing Record 34 of Set 13 | stephenville
# Processing Record 35 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 13 | castro
# Processing Record 37 of Set 13 | ponta do sol
# Processing Record 38 of Set 13 | saldanha
# Processing Record 39 of Set 13 | lillebonne
# Processing Record 40 of Set 13 | olymskiy
# City not found. Skipping...
# Processing Record 41 of Set 13 | sao filipe
# Processing Record 42 of Set 13 | bambous virieux
# Processing Record 43 of Set 13 | antofagasta
# Processing Record 44 of Set 13 | busselton
# Processing Record 45 of Set 13 | punta arenas
# Processing Record 46 of Set 13 | guerrero negro
# Processing Record 47 of Set 13 | ushuaia
# Processing Record 48 of Set 13 | east london
# Processing Record 49 of Set 13 | port alfred
# Processing Record 50 of Set 13 | hilo
# Processing Record 1 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 2 of Set 14 | dikson
# Processing Record 3 of Set 14 | bubaque
# Processing Record 4 of Set 14 | hervey bay
# Processing Record 5 of Set 14 | vao
# Processing Record 6 of Set 14 | bojnurd
# Processing Record 7 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 14 | cherskiy
# Processing Record 9 of Set 14 | kruisfontein
# Processing Record 10 of Set 14 | mahibadhoo
# Processing Record 11 of Set 14 | saint-philippe
# Processing Record 12 of Set 14 | anloga
# Processing Record 13 of Set 14 | tuktoyaktuk
# Processing Record 14 of Set 14 | dzhebariki-khaya
# Processing Record 15 of Set 14 | tessalit
# Processing Record 16 of Set 14 | wucheng
# Processing Record 17 of Set 14 | haysville
# Processing Record 18 of Set 14 | mudgee
# Processing Record 19 of Set 14 | yellowknife
# Processing Record 20 of Set 14 | chokurdakh
# Processing Record 21 of Set 14 | yar-sale
# Processing Record 22 of Set 14 | shiloh
# Processing Record 23 of Set 14 | lebu
# Processing Record 24 of Set 14 | puerto ayora
# Processing Record 25 of Set 14 | khatanga
# Processing Record 26 of Set 14 | sambava
# Processing Record 27 of Set 14 | butaritari
# Processing Record 28 of Set 14 | ancud
# Processing Record 29 of Set 14 | oranjemund
# Processing Record 30 of Set 14 | karaidel
# Processing Record 31 of Set 14 | gebre guracha
# Processing Record 32 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | havre-saint-pierre
# Processing Record 35 of Set 14 | coahuayana
# Processing Record 36 of Set 14 | faanui
# Processing Record 37 of Set 14 | las animas
# Processing Record 38 of Set 14 | gornopravdinsk
# Processing Record 39 of Set 14 | hasaki
# Processing Record 40 of Set 14 | ridgecrest
# Processing Record 41 of Set 14 | makakilo city
# Processing Record 42 of Set 14 | fairbanks
# Processing Record 43 of Set 14 | kiunga
# Processing Record 44 of Set 14 | victoria
# Processing Record 45 of Set 14 | taseyevo
# Processing Record 46 of Set 14 | hermanus
# Processing Record 47 of Set 14 | balkhash
# Processing Record 48 of Set 14 | beringovskiy
# Processing Record 49 of Set 14 | georgetown
# Processing Record 50 of Set 14 | jamestown
# Processing Record 1 of Set 15 | aden
# Processing Record 2 of Set 15 | te anau
# Processing Record 3 of Set 15 | mahebourg
# Processing Record 4 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 15 | yarada
# Processing Record 6 of Set 15 | tabory
# Processing Record 7 of Set 15 | savonlinna
# Processing Record 8 of Set 15 | yerbogachen
# Processing Record 9 of Set 15 | abancay
# Processing Record 10 of Set 15 | bredasdorp
# Processing Record 11 of Set 15 | kodiak
# Processing Record 12 of Set 15 | san francisco
# Processing Record 13 of Set 15 | atuona
# Processing Record 14 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 15 | palamuse
# Processing Record 16 of Set 15 | barrow
# Processing Record 17 of Set 15 | lerik
# Processing Record 18 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 15 | geraldton
# Processing Record 20 of Set 15 | zeya
# Processing Record 21 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 15 | saint anthony
# Processing Record 23 of Set 15 | coihaique
# Processing Record 24 of Set 15 | provideniya
# Processing Record 25 of Set 15 | gresham
# Processing Record 26 of Set 15 | eureka
# Processing Record 27 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 15 | maceio
# Processing Record 29 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 15 | lebedyn
# Processing Record 31 of Set 15 | tiksi
# Processing Record 32 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 15 | tasiilaq
# Processing Record 34 of Set 15 | palora
# Processing Record 35 of Set 15 | aktau
# Processing Record 36 of Set 15 | luderitz
# Processing Record 37 of Set 15 | avarua
# Processing Record 38 of Set 15 | mbandaka
# Processing Record 39 of Set 15 | yarmouth
# Processing Record 40 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 41 of Set 15 | tommot
# Processing Record 42 of Set 15 | ucluelet
# Processing Record 43 of Set 15 | fort nelson
# Processing Record 44 of Set 15 | sept-iles
# Processing Record 45 of Set 15 | kaitangata
# Processing Record 46 of Set 15 | afua
# Processing Record 47 of Set 15 | estelle
# Processing Record 48 of Set 15 | valparaiso
# Processing Record 49 of Set 15 | hofn
# Processing Record 50 of Set 15 | tamandare
# Processing Record 1 of Set 16 | itarema
# Processing Record 2 of Set 16 | le vauclin
# Processing Record 3 of Set 16 | inverness
# Processing Record 4 of Set 16 | dunedin
# Processing Record 5 of Set 16 | korla
# Processing Record 6 of Set 16 | kodinsk
# Processing Record 7 of Set 16 | fortuna
# Processing Record 8 of Set 16 | basoko
# Processing Record 9 of Set 16 | bac lieu
# Processing Record 10 of Set 16 | dwarka
# Processing Record 11 of Set 16 | cabo san lucas
# Processing Record 12 of Set 16 | mananara
# Processing Record 13 of Set 16 | bethel
# Processing Record 14 of Set 16 | kavieng
# Processing Record 15 of Set 16 | minas
# Processing Record 16 of Set 16 | pisco
# Processing Record 17 of Set 16 | tecolutla
# Processing Record 18 of Set 16 | shingu
# Processing Record 19 of Set 16 | xam nua
# Processing Record 20 of Set 16 | aksu
# Processing Record 21 of Set 16 | shenjiamen
# Processing Record 22 of Set 16 | belmonte
# Processing Record 23 of Set 16 | qasigiannguit
# Processing Record 24 of Set 16 | sitka
# Processing Record 25 of Set 16 | nelson bay
# Processing Record 26 of Set 16 | constitucion
# Processing Record 27 of Set 16 | laguna
# Processing Record 28 of Set 16 | barabai
# Processing Record 29 of Set 16 | hit
# Processing Record 30 of Set 16 | los llanos de aridane
# Processing Record 31 of Set 16 | ribeira grande
# Processing Record 32 of Set 16 | mbekenyera
# Processing Record 33 of Set 16 | merauke
# Processing Record 34 of Set 16 | katsuura
# Processing Record 35 of Set 16 | mayo
# Processing Record 36 of Set 16 | kiama
# Processing Record 37 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 16 | batagay
# Processing Record 39 of Set 16 | gizo
# Processing Record 40 of Set 16 | longyearbyen
# Processing Record 41 of Set 16 | namtsy
# Processing Record 42 of Set 16 | luau
# Processing Record 43 of Set 16 | tuatapere
# Processing Record 44 of Set 16 | pervomayskoye
# Processing Record 45 of Set 16 | mehamn
# Processing Record 46 of Set 16 | chuy
# Processing Record 47 of Set 16 | kahului
# Processing Record 48 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 16 | fengxian
# Processing Record 50 of Set 16 | elizabeth city
# Processing Record 1 of Set 17 | lavrentiya
# Processing Record 2 of Set 17 | saravan
# Processing Record 3 of Set 17 | bedburg
# Processing Record 4 of Set 17 | do gonbadan
# Processing Record 5 of Set 17 | bardiyah
# Processing Record 6 of Set 17 | vardo
# Processing Record 7 of Set 17 | new norfolk
# Processing Record 8 of Set 17 | jardim
# Processing Record 9 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 17 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 17 | namie
# Processing Record 12 of Set 17 | vicuna
# Processing Record 13 of Set 17 | faya
# Processing Record 14 of Set 17 | talnakh
# Processing Record 15 of Set 17 | deputatskiy
# Processing Record 16 of Set 17 | ho chi minh city
# Processing Record 17 of Set 17 | semnan
# Processing Record 18 of Set 17 | nanortalik
# Processing Record 19 of Set 17 | sibolga
# Processing Record 20 of Set 17 | hami
# Processing Record 21 of Set 17 | karratha
# Processing Record 22 of Set 17 | imbituba
# Processing Record 23 of Set 17 | port hedland
# Processing Record 24 of Set 17 | bakchar
# Processing Record 25 of Set 17 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 17 | preobrazheniye
# Processing Record 28 of Set 17 | gat
# Processing Record 29 of Set 17 | aquiraz
# Processing Record 30 of Set 17 | port elizabeth
# Processing Record 31 of Set 17 | naze
# Processing Record 32 of Set 17 | tazovskiy
# Processing Record 33 of Set 17 | port lincoln
# Processing Record 34 of Set 17 | xiongyue
# Processing Record 35 of Set 17 | waipawa
# Processing Record 36 of Set 17 | lompoc
# Processing Record 37 of Set 17 | izumo
# Processing Record 38 of Set 17 | half moon bay
# Processing Record 39 of Set 17 | paamiut
# Processing Record 40 of Set 17 | oleksandrivka
# Processing Record 41 of Set 17 | sabang
# Processing Record 42 of Set 17 | tuensang
# Processing Record 43 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 17 | lorengau
# Processing Record 45 of Set 17 | bafata
# Processing Record 46 of Set 17 | wattegama
# Processing Record 47 of Set 17 | kangaatsiaq
# Processing Record 48 of Set 17 | westport
# Processing Record 49 of Set 17 | harper
# Processing Record 50 of Set 17 | upernavik
# Processing Record 1 of Set 18 | vila do maio
# Processing Record 2 of Set 18 | cullen
# Processing Record 3 of Set 18 | koboko
# Processing Record 4 of Set 18 | gangarampur
# Processing Record 5 of Set 18 | dingle
# Processing Record 6 of Set 18 | oistins
# Processing Record 7 of Set 18 | prieska
# Processing Record 8 of Set 18 | shagonar
# Processing Record 9 of Set 18 | san pedro
# Processing Record 10 of Set 18 | sisimiut
# Processing Record 11 of Set 18 | qiongshan
# Processing Record 12 of Set 18 | mersing
# Processing Record 13 of Set 18 | derzhavinsk
# Processing Record 14 of Set 18 | guanica
# Processing Record 15 of Set 18 | lucapa
# Processing Record 16 of Set 18 | el silencio
# Processing Record 17 of Set 18 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 18 | san rafael
# Processing Record 19 of Set 18 | pimentel
# Processing Record 20 of Set 18 | oktyabrskoye
# Processing Record 21 of Set 18 | vila franca do campo
# Processing Record 22 of Set 18 | hualmay
# Processing Record 23 of Set 18 | torbay
# Processing Record 24 of Set 18 | aginskoye
# Processing Record 25 of Set 18 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 18 | fukue
# Processing Record 27 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 18 | birjand
# Processing Record 29 of Set 18 | banda aceh
# Processing Record 30 of Set 18 | saskylakh
# Processing Record 31 of Set 18 | necochea
# Processing Record 32 of Set 18 | matara
# Processing Record 33 of Set 18 | manaul
# Processing Record 34 of Set 18 | thompson
# Processing Record 35 of Set 18 | aswan
# Processing Record 36 of Set 18 | broken hill
# Processing Record 37 of Set 18 | develi
# Processing Record 38 of Set 18 | lasa
# Processing Record 39 of Set 18 | donje vukovije
# City not found. Skipping...
# Processing Record 40 of Set 18 | zavodskoy
# Processing Record 41 of Set 18 | aasiaat
# Processing Record 42 of Set 18 | taltal
# Processing Record 43 of Set 18 | turukhansk
# Processing Record 44 of Set 18 | hope
# Processing Record 45 of Set 18 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 18 | glen cove
# Processing Record 47 of Set 18 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 18 | burica
# City not found. Skipping...
# Processing Record 49 of Set 18 | mogochin
# City not found. Skipping...
# Processing Record 50 of Set 18 | north bend
# Processing Record 1 of Set 19 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 19 | sur
# Processing Record 3 of Set 19 | madimba
# Processing Record 4 of Set 19 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 19 | adrar
# Processing Record 6 of Set 19 | bentong
# Processing Record 7 of Set 19 | teya
# Processing Record 8 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 19 | sumy
# Processing Record 10 of Set 19 | oktyabrskiy
# Processing Record 11 of Set 19 | zivinice
# Processing Record 12 of Set 19 | kiruna
# Processing Record 13 of Set 19 | valdivia
# Processing Record 14 of Set 19 | kaduna
# Processing Record 15 of Set 19 | mnogovershinnyy
# Processing Record 16 of Set 19 | solnechnyy
# Processing Record 17 of Set 19 | aklavik
# Processing Record 18 of Set 19 | skibbereen
# Processing Record 19 of Set 19 | pevek
# Processing Record 20 of Set 19 | bereda
# Processing Record 21 of Set 19 | parsabad
# Processing Record 22 of Set 19 | airai
# Processing Record 23 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 19 | maravilha
# Processing Record 25 of Set 19 | hithadhoo
# Processing Record 26 of Set 19 | parana
# Processing Record 27 of Set 19 | tura
# Processing Record 28 of Set 19 | nemuro
# Processing Record 29 of Set 19 | qixingtai
# Processing Record 30 of Set 19 | nadym
# Processing Record 31 of Set 19 | port moresby
# Processing Record 32 of Set 19 | magugu
# Processing Record 33 of Set 19 | thai binh
# Processing Record 34 of Set 19 | lagunas
# Processing Record 35 of Set 19 | iwanai
# Processing Record 36 of Set 19 | martapura
# Processing Record 37 of Set 19 | komsomolskiy
# Processing Record 38 of Set 19 | inuvik
# Processing Record 39 of Set 19 | boa vista
# Processing Record 40 of Set 19 | vostok
# Processing Record 41 of Set 19 | ust-maya
# Processing Record 42 of Set 19 | inhambane
# Processing Record 43 of Set 19 | stillwater
# Processing Record 44 of Set 19 | west plains
# Processing Record 45 of Set 19 | luwuk
# Processing Record 46 of Set 19 | samarai
# Processing Record 47 of Set 19 | chapais
# Processing Record 48 of Set 19 | berlevag
# Processing Record 49 of Set 19 | atasu
# Processing Record 50 of Set 19 | gorontalo
# Processing Record 1 of Set 20 | miraflores
# Processing Record 2 of Set 20 | floro
# Processing Record 3 of Set 20 | watertown
# Processing Record 4 of Set 20 | zhigansk
# Processing Record 5 of Set 20 | garut
# Processing Record 6 of Set 20 | puerto rondon
# Processing Record 7 of Set 20 | marshfield
# Processing Record 8 of Set 20 | roald
# Processing Record 9 of Set 20 | sinazongwe
# Processing Record 10 of Set 20 | manbij
# Processing Record 11 of Set 20 | eunice
# Processing Record 12 of Set 20 | aleksandrov gay
# Processing Record 13 of Set 20 | chicama
# Processing Record 14 of Set 20 | moose factory
# Processing Record 15 of Set 20 | kayiry
# Processing Record 16 of Set 20 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 20 | dire dawa
# Processing Record 18 of Set 20 | iskateley
# Processing Record 19 of Set 20 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 20 | mirpur mathelo
# Processing Record 21 of Set 20 | namatanai
# Processing Record 22 of Set 20 | guiuan
# Processing Record 23 of Set 20 | caetite
# Processing Record 24 of Set 20 | marsa matruh
# Processing Record 25 of Set 20 | ibra
# Processing Record 26 of Set 20 | verkhnyaya inta
# Processing Record 27 of Set 20 | narsaq
# Processing Record 28 of Set 20 | khandyga
# Processing Record 29 of Set 20 | cayenne
# Processing Record 30 of Set 20 | panalingaan
# Processing Record 31 of Set 20 | bahia blanca
# Processing Record 32 of Set 20 | umm kaddadah
# Processing Record 33 of Set 20 | khaga
# Processing Record 34 of Set 20 | doha
# Processing Record 35 of Set 20 | puerto baquerizo moreno
# Processing Record 36 of Set 20 | vitim
# Processing Record 37 of Set 20 | ayagoz
# Processing Record 38 of Set 20 | carnarvon
# Processing Record 39 of Set 20 | marsh harbour
# Processing Record 40 of Set 20 | sayyan
# Processing Record 41 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 20 | wuwei
# Processing Record 43 of Set 20 | grindavik
# Processing Record 44 of Set 20 | andselv
# City not found. Skipping...
# Processing Record 45 of Set 20 | bonga
# Processing Record 46 of Set 20 | san patricio
# Processing Record 47 of Set 20 | bengkulu
# Processing Record 48 of Set 20 | bud
# Processing Record 49 of Set 20 | ouesso
# Processing Record 50 of Set 20 | hanzhong
# Processing Record 1 of Set 21 | candawaga
# City not found. Skipping...
# Processing Record 2 of Set 21 | tarko-sale
# Processing Record 3 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 21 | la ronge
# Processing Record 5 of Set 21 | almaznyy
# Processing Record 6 of Set 21 | prinza
# Processing Record 7 of Set 21 | ichinoseki
# Processing Record 8 of Set 21 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 21 | athens
# Processing Record 10 of Set 21 | mareeba
# Processing Record 11 of Set 21 | olafsvik
# Processing Record 12 of Set 21 | vangaindrano
# Processing Record 13 of Set 21 | zolotukhino
# Processing Record 14 of Set 21 | mana
# Processing Record 15 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 21 | peine
# Processing Record 17 of Set 21 | shu
# Processing Record 18 of Set 21 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 21 | madison heights
# Processing Record 20 of Set 21 | ketchikan
# Processing Record 21 of Set 21 | petit-canal
# Processing Record 22 of Set 21 | tautira
# Processing Record 23 of Set 21 | moerai
# Processing Record 24 of Set 21 | petropavlovskoye
# Processing Record 25 of Set 21 | khairagarh
# Processing Record 26 of Set 21 | gillette
# Processing Record 27 of Set 21 | voivodeni
# Processing Record 28 of Set 21 | detchino
# Processing Record 29 of Set 21 | verkhoyansk
# Processing Record 30 of Set 21 | micheweni
# Processing Record 31 of Set 21 | souillac
# Processing Record 32 of Set 21 | lundamo
# Processing Record 33 of Set 21 | desnogorsk
# Processing Record 34 of Set 21 | turayf
# Processing Record 35 of Set 21 | kifri
# Processing Record 36 of Set 21 | redlands
# Processing Record 37 of Set 21 | padang
# Processing Record 38 of Set 21 | krasnyy chikoy
# Processing Record 39 of Set 21 | ho
# City not found. Skipping...
# Processing Record 40 of Set 21 | benjamin constant
# Processing Record 41 of Set 21 | okhotsk
# Processing Record 42 of Set 21 | lewiston
# Processing Record 43 of Set 21 | gimli
# Processing Record 44 of Set 21 | aksay
# Processing Record 45 of Set 21 | aksarka
# Processing Record 46 of Set 21 | homer
# Processing Record 47 of Set 21 | porto novo
# Processing Record 48 of Set 21 | durban
# Processing Record 49 of Set 21 | kathu
# Processing Record 50 of Set 21 | ordu
# Processing Record 1 of Set 22 | shakawe
# Processing Record 2 of Set 22 | nuuk
# Processing Record 3 of Set 22 | eyl
# Processing Record 4 of Set 22 | winnemucca
# Processing Record 5 of Set 22 | puerto escondido
# Processing Record 6 of Set 22 | manzil tamim
# City not found. Skipping...
# Processing Record 7 of Set 22 | norman wells
# Processing Record 8 of Set 22 | svetlyy
# Processing Record 9 of Set 22 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 22 | pacific grove
# Processing Record 11 of Set 22 | kasongo-lunda
# Processing Record 12 of Set 22 | pasighat
# Processing Record 13 of Set 22 | ratnagiri
# Processing Record 14 of Set 22 | raver
# Processing Record 15 of Set 22 | mandalgovi
# Processing Record 16 of Set 22 | coquimbo
# Processing Record 17 of Set 22 | bilma
# Processing Record 18 of Set 22 | pulandian
# Processing Record 19 of Set 22 | brownsville
# Processing Record 20 of Set 22 | onda
# Processing Record 21 of Set 22 | gerash
# Processing Record 22 of Set 22 | cockburn town
# Processing Record 23 of Set 22 | klaksvik
# Processing Record 24 of Set 22 | brae
# Processing Record 25 of Set 22 | port blair
# Processing Record 26 of Set 22 | kutum
# Processing Record 27 of Set 22 | state college
# Processing Record 28 of Set 22 | haines junction
# Processing Record 29 of Set 22 | conroe
# Processing Record 30 of Set 22 | takoradi
# Processing Record 31 of Set 22 | malanje
# Processing Record 32 of Set 22 | xinyu
# Processing Record 33 of Set 22 | stolin
# Processing Record 34 of Set 22 | ostrovnoy
# Processing Record 35 of Set 22 | surgut
# Processing Record 36 of Set 22 | moron
# Processing Record 37 of Set 22 | christchurch
# Processing Record 38 of Set 22 | namibe
# Processing Record 39 of Set 22 | xanxere
# Processing Record 40 of Set 22 | sao joao da barra
# Processing Record 41 of Set 22 | sao felix do xingu
# Processing Record 42 of Set 22 | port augusta
# Processing Record 43 of Set 22 | bom jardim
# Processing Record 44 of Set 22 | andujar
# Processing Record 45 of Set 22 | camacha
# Processing Record 46 of Set 22 | lazaro cardenas
# Processing Record 47 of Set 22 | belaya gora
# Processing Record 48 of Set 22 | muros
# Processing Record 49 of Set 22 | vila
# Processing Record 50 of Set 22 | umm lajj
# Processing Record 1 of Set 23 | lashio
# Processing Record 2 of Set 23 | henties bay
# Processing Record 3 of Set 23 | kavaratti
# Processing Record 4 of Set 23 | kamenka
# Processing Record 5 of Set 23 | mocuba
# Processing Record 6 of Set 23 | bansko
# Processing Record 7 of Set 23 | etchoropo
# Processing Record 8 of Set 23 | cabra
# Processing Record 9 of Set 23 | esso
# Processing Record 10 of Set 23 | boda
# Processing Record 11 of Set 23 | wanaka
# Processing Record 12 of Set 23 | mount pleasant
# Processing Record 13 of Set 23 | gao
# Processing Record 14 of Set 23 | quatre cocos
# Processing Record 15 of Set 23 | yulara
# Processing Record 16 of Set 23 | san luis
# Processing Record 17 of Set 23 | el dorado
# Processing Record 18 of Set 23 | shahr-e babak
# Processing Record 19 of Set 23 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 23 | balkanabat
# Processing Record 21 of Set 23 | wexford
# Processing Record 22 of Set 23 | sukumo
# Processing Record 23 of Set 23 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 23 | ilulissat
# Processing Record 25 of Set 23 | gucheng
# Processing Record 26 of Set 23 | luanda
# Processing Record 27 of Set 23 | marzuq
# Processing Record 28 of Set 23 | banepa
# Processing Record 29 of Set 23 | maneadero
# Processing Record 30 of Set 23 | scottsbluff
# Processing Record 31 of Set 23 | taitung
# Processing Record 32 of Set 23 | bathsheba
# Processing Record 33 of Set 23 | khorixas
# Processing Record 34 of Set 23 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 23 | ronneby
# Processing Record 36 of Set 23 | luban
# Processing Record 37 of Set 23 | briancon
# Processing Record 38 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 23 | lagoa
# Processing Record 40 of Set 23 | mirabad
# Processing Record 41 of Set 23 | altay
# Processing Record 42 of Set 23 | cairns
# Processing Record 43 of Set 23 | bay roberts
# Processing Record 44 of Set 23 | revda
# Processing Record 45 of Set 23 | atagay
# Processing Record 46 of Set 23 | beeskow
# Processing Record 47 of Set 23 | bekovo
# Processing Record 48 of Set 23 | avera
# Processing Record 49 of Set 23 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 23 | sucua
# Processing Record 1 of Set 24 | bagdarin
# Processing Record 2 of Set 24 | viedma
# Processing Record 3 of Set 24 | tabou
# Processing Record 4 of Set 24 | araouane
# Processing Record 5 of Set 24 | kwinana
# Processing Record 6 of Set 24 | naron
# Processing Record 7 of Set 24 | agirish
# Processing Record 8 of Set 24 | lampazos de naranjo
# Processing Record 9 of Set 24 | healdsburg
# Processing Record 10 of Set 24 | sarangani
# Processing Record 11 of Set 24 | sesheke
# Processing Record 12 of Set 24 | beyneu
# Processing Record 13 of Set 24 | pangnirtung
# Processing Record 14 of Set 24 | qalyub
# Processing Record 15 of Set 24 | port hardy
# Processing Record 16 of Set 24 | ahipara
# Processing Record 17 of Set 24 | srednekolymsk
# Processing Record 18 of Set 24 | tukrah
# Processing Record 19 of Set 24 | santiago de cuba
# Processing Record 20 of Set 24 | danilovka
# Processing Record 21 of Set 24 | chapleau
# Processing Record 22 of Set 24 | saint-francois
# Processing Record 23 of Set 24 | wanning
# Processing Record 24 of Set 24 | varjota
# Processing Record 25 of Set 24 | tiarei
# Processing Record 26 of Set 24 | taoudenni
# Processing Record 27 of Set 24 | haapu
# City not found. Skipping...
# Processing Record 28 of Set 24 | caucaia
# Processing Record 29 of Set 24 | aripuana
# Processing Record 30 of Set 24 | walvis bay
# Processing Record 31 of Set 24 | kerman
# Processing Record 32 of Set 24 | poum
# Processing Record 33 of Set 24 | dicabisagan
# Processing Record 34 of Set 24 | talcahuano
# Processing Record 35 of Set 24 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 24 | xining
# Processing Record 37 of Set 24 | kaniama
# Processing Record 38 of Set 24 | san cristobal
# Processing Record 39 of Set 24 | armacao dos buzios
# City not found. Skipping...
# Processing Record 40 of Set 24 | flinders
# Processing Record 41 of Set 24 | saint-joseph
# Processing Record 42 of Set 24 | ciudad bolivar
# Processing Record 43 of Set 24 | sucre
# Processing Record 44 of Set 24 | ornskoldsvik
# Processing Record 45 of Set 24 | svetlaya
# Processing Record 46 of Set 24 | grosseto
# Processing Record 47 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 24 | saint-pierre
# Processing Record 49 of Set 24 | bonthe
# Processing Record 50 of Set 24 | uren
# Processing Record 1 of Set 25 | blanes
# Processing Record 2 of Set 25 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 25 | orthez
# Processing Record 4 of Set 25 | mount gambier
# Processing Record 5 of Set 25 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 25 | zyryanovsk
# Processing Record 7 of Set 25 | broome
# Processing Record 8 of Set 25 | anadyr
# Processing Record 9 of Set 25 | shellbrook
# Processing Record 10 of Set 25 | nieuw amsterdam
# Processing Record 11 of Set 25 | sale
# Processing Record 12 of Set 25 | holzminden
# Processing Record 13 of Set 25 | shimoga
# Processing Record 14 of Set 25 | ayna
# Processing Record 15 of Set 25 | kemise
# Processing Record 16 of Set 25 | ballina
# Processing Record 17 of Set 25 | tres arroyos
# Processing Record 18 of Set 25 | kwekwe
# Processing Record 19 of Set 25 | claremore
# Processing Record 20 of Set 25 | seoul
# Processing Record 21 of Set 25 | naryan-mar
# Processing Record 22 of Set 25 | xuddur
# Processing Record 23 of Set 25 | sobolevo
# Processing Record 24 of Set 25 | baykalovo
# Processing Record 25 of Set 25 | jacareacanga
# Processing Record 26 of Set 25 | iqaluit
# Processing Record 27 of Set 25 | mitsamiouli
# Processing Record 28 of Set 25 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 25 | hovd
# Processing Record 30 of Set 25 | kalomo
# City not found. Skipping...
# Processing Record 31 of Set 25 | aguimes
# Processing Record 32 of Set 25 | manavalakurichi
# Processing Record 33 of Set 25 | itoman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint George  37.1041 -113.5841     40.24        31           0
# 1     Codrington -38.2667  141.9667     67.28        59          77
# 2        Rikitea -23.1203 -134.9692     78.08        74         100
# 3         Albany  42.6001  -73.9662     38.19        91         100
# 4     Vila Velha -20.3297  -40.2925     75.15        95          40
# 5  Batagay-Alyta  67.8006  130.4114    -16.46        97          99
# 6         Hobart -42.8794  147.3294     74.12        47          20
# 7          Bluff -46.6000  168.3333     52.81        84         100
# 8     Nikolskoye  59.7035   30.7861     -0.09       100         100
# 9        Shimoda  34.6667  138.9500     46.76        64         100
#
#    Wind Speed Country Current Description
# 0        1.01      US           clear sky
# 1       14.92      AU       broken clouds
# 2       18.41      PF     overcast clouds
# 3        1.99      US                snow
# 4        6.91      BR          light rain
# 5        3.04      RU     overcast clouds
# 6        1.99      AU          few clouds
# 7        3.29      NZ          light rain
# 8        2.77      RU     overcast clouds
# 9        1.74      JP     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint George      US  37.1041 -113.5841     40.24        31           0
# 1     Codrington      AU -38.2667  141.9667     67.28        59          77
# 2        Rikitea      PF -23.1203 -134.9692     78.08        74         100
# 3         Albany      US  42.6001  -73.9662     38.19        91         100
# 4     Vila Velha      BR -20.3297  -40.2925     75.15        95          40
# 5  Batagay-Alyta      RU  67.8006  130.4114    -16.46        97          99
# 6         Hobart      AU -42.8794  147.3294     74.12        47          20
# 7          Bluff      NZ -46.6000  168.3333     52.81        84         100
# 8     Nikolskoye      RU  59.7035   30.7861     -0.09       100         100
# 9        Shimoda      JP  34.6667  138.9500     46.76        64         100
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1       14.92       broken clouds
# 2       18.41     overcast clouds
# 3        1.99                snow
# 4        6.91          light rain
# 5        3.04     overcast clouds
# 6        1.99          few clouds
# 7        3.29          light rain
# 8        2.77     overcast clouds
# 9        1.74     overcast clouds

# %%
# Export the DataFrame as a CSV file.
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
